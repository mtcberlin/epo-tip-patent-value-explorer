# %% [markdown]
# # Patent Value Explorer
#
# This notebook launches the **Patent Value Explorer** SvelteKit application on EPO TIP's JupyterHub.
#
# ## Prerequisites
#
# - **Node.js 22+** installed and available in PATH
# - **pnpm** package manager installed (`npm install -g pnpm`)
#
# ## Quick Start
#
# Click **Run All** to install dependencies, build the app, and start the server.
# A clickable link will appear below once the server is ready.

# %%
from launch import launch, stop

# %%
launch()

# %% [markdown]
# ## Usage
#
# Click the link printed above to open the Patent Value Explorer in a new tab.
#
# When you are done, run the cell below to stop the server.

# %%
stop()
